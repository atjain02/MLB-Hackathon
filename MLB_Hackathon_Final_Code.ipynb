# %%
# !pip install fair-esm
# Out:
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl.metadata (37 kB)
# Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 9.9 MB/s eta 0:00:00
# Installing collected packages: fair-esm
# Successfully installed fair-esm-2.0.0

# %%
import os
import numpy as np
import pandas as pd
import re
import torch
import esm
from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("Loading ESM model...")
model_esm, alphabet = esm.pretrained.esm1_t34_670M_UR50S()
batch_converter = alphabet.get_batch_converter()
model_esm.eval()
model_esm.to(device)
print("ESM model loaded.")
# Out:
# Using device: cuda
# Loading ESM model...
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm1_t34_670M_UR50S.pt" to /root/.cache/torch/hub/checkpoints/esm1_t34_670M_UR50S.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm1_t34_670M_UR50S-contact-regression.pt" to /root/.cache/torch/hub/checkpoints/esm1_t34_670M_UR50S-contact-regression.pt
# ESM model loaded.

# %%
def generate_mutant_sequence(mut_str, wt_seq):
    m = re.match(r"([A-Z])(\d+)([A-Z])", mut_str)
    if m:
        orig_letter, pos_str, mut_letter = m.groups()
        pos = int(pos_str)
        mutated_seq = wt_seq[:pos-1] + mut_letter + wt_seq[pos:]
        return mutated_seq, orig_letter, mut_letter, pos
    else:
        return None, None, None, None

def get_batch_embeddings(sequences, batch_converter, model_esm, device, batch_size=8):
    all_embeddings = []
    total = len(sequences)
    num_batches = (total - 1) // batch_size + 1
    for i in range(0, total, batch_size):
        batch_seqs = sequences[i:i+batch_size]
        data = [(str(i+j), seq) for j, seq in enumerate(batch_seqs)]
        batch_labels, batch_strs, batch_tokens = batch_converter(data)
        batch_tokens = batch_tokens.to(device)
        with torch.no_grad():
            results = model_esm(batch_tokens, repr_layers=[34], return_contacts=False)
        token_representations = results["representations"][34]
        # Average pooling over tokens
        embeddings = token_representations.mean(1).cpu().numpy()
        all_embeddings.append(embeddings)
        print(f"Processed batch {i//batch_size + 1}/{num_batches}")
        # Free up unused GPU memory
        torch.cuda.empty_cache()
    return np.vstack(all_embeddings)

def extract_all_features(df, wt_seq, hydropathy, batch_size=8):
    engineered_features = []
    mutated_seqs = []
    for mut in df['mutant']:
        mutated_seq, orig_letter, mut_letter, pos = generate_mutant_sequence(mut, wt_seq)
        if mutated_seq is None:
            engineered_features.append([np.nan, np.nan, np.nan, np.nan])
            mutated_seqs.append("")
        else:
            aa_diff = ord(mut_letter) - ord(orig_letter)
            hydro_orig = hydropathy.get(orig_letter, np.nan)
            hydro_mut = hydropathy.get(mut_letter, np.nan)
            hydro_diff = hydro_mut - hydro_orig if (hydro_orig is not None and hydro_mut is not None) else np.nan
            rel_pos = pos / len(wt_seq)
            engineered_features.append([pos, aa_diff, hydro_diff, rel_pos])
            mutated_seqs.append(mutated_seq)
    engineered_features = np.array(engineered_features)
    embeddings = get_batch_embeddings(mutated_seqs, batch_converter, model_esm, device, batch_size=batch_size)
    features = np.concatenate((engineered_features, embeddings), axis=1)
    return features

# %%
hydropathy = {
    'A': 1.8, 'R': -4.5, 'N': -3.5, 'D': -3.5, 'C': 2.5,
    'Q': -3.5, 'E': -3.5, 'G': -0.4, 'H': -3.2, 'I': 4.5,
    'L': 3.8, 'K': -3.9, 'M': 1.9, 'F': 2.8, 'P': -1.6,
    'S': -0.8, 'T': -0.7, 'W': -0.9, 'Y': -1.3, 'V': 4.2
}

with open('sequence.fasta', 'r') as f:
    lines = f.readlines()
    wt_sequence = "".join(line.strip() for line in lines if not line.startswith('>'))
print("Wild-type sequence loaded. Length:", len(wt_sequence))

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
print("\nTraining data preview:")
print(train_df.head())
print("\nTest data preview:")
print(test_df.head())
# Out:
# Wild-type sequence loaded. Length: 656
#
# Training data preview:
#   mutant  DMS_score
# 0    M0Y     0.2730
# 1    M0W     0.2857
# 2    M0V     0.2153
# 3    M0T     0.3122
# 4    M0S     0.2180
#
# Test data preview:
#   mutant
# 0    V1D
# 1    V1Y
# 2    V1C
# 3    V1A
# 4    V1E

# %%
print("\nExtracting features for training data using batching...")
train_features = extract_all_features(train_df, wt_sequence, hydropathy, batch_size=8)
print("Training features shape:", train_features.shape)
print("\nExtracting features for test data using batching...")
test_features = extract_all_features(test_df, wt_sequence, hydropathy, batch_size=8)
print("Test features shape:", test_features.shape)
y_train_full = train_df['DMS_score'].values
print("\nSplitting data into training and validation sets...")
X_train, X_val, y_train, y_val = train_test_split(train_features, y_train_full, test_size=0.2, random_state=42)
print("X_train shape:", X_train.shape, "| X_val shape:", X_val.shape)
# Out:
# Extracting features for training data using batching...
# Processed batch 1/168
# Processed batch 2/168
# Processed batch 3/168
# Processed batch 4/168
# Processed batch 5/168
# Processed batch 6/168
# Processed batch 7/168
# Processed batch 8/168
# Processed batch 9/168
# Processed batch 10/168
# Processed batch 11/168
# Processed batch 12/168
# Processed batch 13/168
# Processed batch 14/168
# Processed batch 15/168
# Processed batch 16/168
# Processed batch 17/168
# Processed batch 18/168
# Processed batch 19/168
# Processed batch 20/168
# Processed batch 21/168
# Processed batch 22/168
# Processed batch 23/168
# Processed batch 24/168
# Processed batch 25/168
# Processed batch 26/168
# Processed batch 27/168
# Processed batch 28/168
# Processed batch 29/168
# Processed batch 30/168
# Processed batch 31/168
# Processed batch 32/168
# Processed batch 33/168
# Processed batch 34/168
# Processed batch 35/168
# Processed batch 36/168
# Processed batch 37/168
# Processed batch 38/168
# Processed batch 39/168
# Processed batch 40/168
# Processed batch 41/168
# Processed batch 42/168
# Processed batch 43/168
# Processed batch 44/168
# Processed batch 45/168
# Processed batch 46/168
# Processed batch 47/168
# Processed batch 48/168
# Processed batch 49/168
# Processed batch 50/168
# Processed batch 51/168
# Processed batch 52/168
# Processed batch 53/168
# Processed batch 54/168
# Processed batch 55/168
# Processed batch 56/168
# Processed batch 57/168
# Processed batch 58/168
# Processed batch 59/168
# Processed batch 60/168
# Processed batch 61/168
# Processed batch 62/168
# Processed batch 63/168
# Processed batch 64/168
# Processed batch 65/168
# Processed batch 66/168
# Processed batch 67/168
# Processed batch 68/168
# Processed batch 69/168
# Processed batch 70/168
# Processed batch 71/168
# Processed batch 72/168
# Processed batch 73/168
# Processed batch 74/168
# Processed batch 75/168
# Processed batch 76/168
# Processed batch 77/168
# Processed batch 78/168
# Processed batch 79/168
# Processed batch 80/168
# Processed batch 81/168
# Processed batch 82/168
# Processed batch 83/168
# Processed batch 84/168
# Processed batch 85/168
# Processed batch 86/168
# Processed batch 87/168
# Processed batch 88/168
# Processed batch 89/168
# Processed batch 90/168
# Processed batch 91/168
# Processed batch 92/168
# Processed batch 93/168
# Processed batch 94/168
# Processed batch 95/168
# Processed batch 96/168
# Processed batch 97/168
# Processed batch 98/168
# Processed batch 99/168
# Processed batch 100/168
# Processed batch 101/168
# Processed batch 102/168
# Processed batch 103/168
# Processed batch 104/168
# Processed batch 105/168
# Processed batch 106/168
# Processed batch 107/168
# Processed batch 108/168
# Processed batch 109/168
# Processed batch 110/168
# Processed batch 111/168
# Processed batch 112/168
# Processed batch 113/168
# Processed batch 114/168
# Processed batch 115/168
# Processed batch 116/168
# Processed batch 117/168
# Processed batch 118/168
# Processed batch 119/168
# Processed batch 120/168
# Processed batch 121/168
# Processed batch 122/168
# Processed batch 123/168
# Processed batch 124/168
# Processed batch 125/168
# Processed batch 126/168
# Processed batch 127/168
# Processed batch 128/168
# Processed batch 129/168
# Processed batch 130/168
# Processed batch 131/168
# Processed batch 132/168
# Processed batch 133/168
# Processed batch 134/168
# Processed batch 135/168
# Processed batch 136/168
# Processed batch 137/168
# Processed batch 138/168
# Processed batch 139/168
# Processed batch 140/168
# Processed batch 141/168
# Processed batch 142/168
# Processed batch 143/168
# Processed batch 144/168
# Processed batch 145/168
# Processed batch 146/168
# Processed batch 147/168
# Processed batch 148/168
# Processed batch 149/168
# Processed batch 150/168
# Processed batch 151/168
# Processed batch 152/168
# Processed batch 153/168
# Processed batch 154/168
# Processed batch 155/168
# Processed batch 156/168
# Processed batch 157/168
# Processed batch 158/168
# Processed batch 159/168
# Processed batch 160/168
# Processed batch 161/168
# Processed batch 162/168
# Processed batch 163/168
# Processed batch 164/168
# Processed batch 165/168
# Processed batch 166/168
# Processed batch 167/168
# Processed batch 168/168
# Training features shape: (1340, 1284)
#
# Extracting features for test data using batching...
# Processed batch 1/1416
# Processed batch 2/1416
# Processed batch 3/1416
# Processed batch 4/1416
# Processed batch 5/1416
# Processed batch 6/1416
# Processed batch 7/1416
# Processed batch 8/1416
# Processed batch 9/1416
# Processed batch 10/1416
# Processed batch 11/1416
# Processed batch 12/1416
# Processed batch 13/1416
# Processed batch 14/1416
# Processed batch 15/1416
# Processed batch 16/1416
# Processed batch 17/1416
# Processed batch 18/1416
# Processed batch 19/1416
# Processed batch 20/1416
# Processed batch 21/1416
# Processed batch 22/1416
# Processed batch 23/1416
# Processed batch 24/1416
# Processed batch 25/1416
# Processed batch 26/1416
# Processed batch 27/1416
# Processed batch 28/1416
# Processed batch 29/1416
# Processed batch 30/1416
# Processed batch 31/1416
# Processed batch 32/1416
# Processed batch 33/1416
# Processed batch 34/1416
# Processed batch 35/1416
# Processed batch 36/1416
# Processed batch 37/1416
# Processed batch 38/1416
# Processed batch 39/1416
# Processed batch 40/1416
# Processed batch 41/1416
# Processed batch 42/1416
# Processed batch 43/1416
# Processed batch 44/1416
# Processed batch 45/1416
# Processed batch 46/1416
# Processed batch 47/1416
# Processed batch 48/1416
# Processed batch 49/1416
# Processed batch 50/1416
# Processed batch 51/1416
# Processed batch 52/1416
# Processed batch 53/1416
# Processed batch 54/1416
# Processed batch 55/1416
# Processed batch 56/1416
# Processed batch 57/1416
# Processed batch 58/1416
# Processed batch 59/1416
# Processed batch 60/1416
# Processed batch 61/1416
# Processed batch 62/1416
# Processed batch 63/1416
# Processed batch 64/1416
# Processed batch 65/1416
# Processed batch 66/1416
# Processed batch 67/1416
# Processed batch 68/1416
# Processed batch 69/1416
# Processed batch 70/1416
# Processed batch 71/1416
# Processed batch 72/1416
# Processed batch 73/1416
# Processed batch 74/1416
# Processed batch 75/1416
# Processed batch 76/1416
# Processed batch 77/1416
# Processed batch 78/1416
# Processed batch 79/1416
# Processed batch 80/1416
# Processed batch 81/1416
# Processed batch 82/1416
# Processed batch 83/1416
# Processed batch 84/1416
# Processed batch 85/1416
# Processed batch 86/1416
# Processed batch 87/1416
# Processed batch 88/1416
# Processed batch 89/1416
# Processed batch 90/1416
# Processed batch 91/1416
# Processed batch 92/1416
# Processed batch 93/1416
# Processed batch 94/1416
# Processed batch 95/1416
# Processed batch 96/1416
# Processed batch 97/1416
# Processed batch 98/1416
# Processed batch 99/1416
# Processed batch 100/1416
# Processed batch 101/1416
# Processed batch 102/1416
# Processed batch 103/1416
# Processed batch 104/1416
# Processed batch 105/1416
# Processed batch 106/1416
# Processed batch 107/1416
# Processed batch 108/1416
# Processed batch 109/1416
# Processed batch 110/1416
# Processed batch 111/1416
# Processed batch 112/1416
# Processed batch 113/1416
# Processed batch 114/1416
# Processed batch 115/1416
# Processed batch 116/1416
# Processed batch 117/1416
# Processed batch 118/1416
# Processed batch 119/1416
# Processed batch 120/1416
# Processed batch 121/1416
# Processed batch 122/1416
# Processed batch 123/1416
# Processed batch 124/1416
# Processed batch 125/1416
# Processed batch 126/1416
# Processed batch 127/1416
# Processed batch 128/1416
# Processed batch 129/1416
# Processed batch 130/1416
# Processed batch 131/1416
# Processed batch 132/1416
# Processed batch 133/1416
# Processed batch 134/1416
# Processed batch 135/1416
# Processed batch 136/1416
# Processed batch 137/1416
# Processed batch 138/1416
# Processed batch 139/1416
# Processed batch 140/1416
# Processed batch 141/1416
# Processed batch 142/1416
# Processed batch 143/1416
# Processed batch 144/1416
# Processed batch 145/1416
# Processed batch 146/1416
# Processed batch 147/1416
# Processed batch 148/1416
# Processed batch 149/1416
# Processed batch 150/1416
# Processed batch 151/1416
# Processed batch 152/1416
# Processed batch 153/1416
# Processed batch 154/1416
# Processed batch 155/1416
# Processed batch 156/1416
# Processed batch 157/1416
# Processed batch 158/1416
# Processed batch 159/1416
# Processed batch 160/1416
# Processed batch 161/1416
# Processed batch 162/1416
# Processed batch 163/1416
# Processed batch 164/1416
# Processed batch 165/1416
# Processed batch 166/1416
# Processed batch 167/1416
# Processed batch 168/1416
# Processed batch 169/1416
# Processed batch 170/1416
# Processed batch 171/1416
# Processed batch 172/1416
# Processed batch 173/1416
# Processed batch 174/1416
# Processed batch 175/1416
# Processed batch 176/1416
# Processed batch 177/1416
# Processed batch 178/1416
# Processed batch 179/1416
# Processed batch 180/1416
# Processed batch 181/1416
# Processed batch 182/1416
# Processed batch 183/1416
# Processed batch 184/1416
# Processed batch 185/1416
# Processed batch 186/1416
# Processed batch 187/1416
# Processed batch 188/1416
# Processed batch 189/1416
# Processed batch 190/1416
# Processed batch 191/1416
# Processed batch 192/1416
# Processed batch 193/1416
# Processed batch 194/1416
# Processed batch 195/1416
# Processed batch 196/1416
# Processed batch 197/1416
# Processed batch 198/1416
# Processed batch 199/1416
# Processed batch 200/1416
# Processed batch 201/1416
# Processed batch 202/1416
# Processed batch 203/1416
# Processed batch 204/1416
# Processed batch 205/1416
# Processed batch 206/1416
# Processed batch 207/1416
# Processed batch 208/1416
# Processed batch 209/1416
# Processed batch 210/1416
# Processed batch 211/1416
# Processed batch 212/1416
# Processed batch 213/1416
# Processed batch 214/1416
# Processed batch 215/1416
# Processed batch 216/1416
# Processed batch 217/1416
# Processed batch 218/1416
# Processed batch 219/1416
# Processed batch 220/1416
# Processed batch 221/1416
# Processed batch 222/1416
# Processed batch 223/1416
# Processed batch 224/1416
# Processed batch 225/1416
# Processed batch 226/1416
# Processed batch 227/1416
# Processed batch 228/1416
# Processed batch 229/1416
# Processed batch 230/1416
# Processed batch 231/1416
# Processed batch 232/1416
# Processed batch 233/1416
# Processed batch 234/1416
# Processed batch 235/1416
# Processed batch 236/1416
# Processed batch 237/1416
# Processed batch 238/1416
# Processed batch 239/1416
# Processed batch 240/1416
# Processed batch 241/1416
# Processed batch 242/1416
# Processed batch 243/1416
# Processed batch 244/1416
# Processed batch 245/1416
# Processed batch 246/1416
# Processed batch 247/1416
# Processed batch 248/1416
# Processed batch 249/1416
# Processed batch 250/1416
# Processed batch 251/1416
# Processed batch 252/1416
# Processed batch 253/1416
# Processed batch 254/1416
# Processed batch 255/1416
# Processed batch 256/1416
# Processed batch 257/1416
# Processed batch 258/1416
# Processed batch 259/1416
# Processed batch 260/1416
# Processed batch 261/1416
# Processed batch 262/1416
# Processed batch 263/1416
# Processed batch 264/1416
# Processed batch 265/1416
# Processed batch 266/1416
# Processed batch 267/1416
# Processed batch 268/1416
# Processed batch 269/1416
# Processed batch 270/1416
# Processed batch 271/1416
# Processed batch 272/1416
# Processed batch 273/1416
# Processed batch 274/1416
# Processed batch 275/1416
# Processed batch 276/1416
# Processed batch 277/1416
# Processed batch 278/1416
# Processed batch 279/1416
# Processed batch 280/1416
# Processed batch 281/1416
# Processed batch 282/1416
# Processed batch 283/1416
# Processed batch 284/1416
# Processed batch 285/1416
# Processed batch 286/1416
# Processed batch 287/1416
# Processed batch 288/1416
# Processed batch 289/1416
# Processed batch 290/1416
# Processed batch 291/1416
# Processed batch 292/1416
# Processed batch 293/1416
# Processed batch 294/1416
# Processed batch 295/1416
# Processed batch 296/1416
# Processed batch 297/1416
# Processed batch 298/1416
# Processed batch 299/1416
# Processed batch 300/1416
# Processed batch 301/1416
# Processed batch 302/1416
# Processed batch 303/1416
# Processed batch 304/1416
# Processed batch 305/1416
# Processed batch 306/1416
# Processed batch 307/1416
# Processed batch 308/1416
# Processed batch 309/1416
# Processed batch 310/1416
# Processed batch 311/1416
# Processed batch 312/1416
# Processed batch 313/1416
# Processed batch 314/1416
# Processed batch 315/1416
# Processed batch 316/1416
# Processed batch 317/1416
# Processed batch 318/1416
# Processed batch 319/1416
# Processed batch 320/1416
# Processed batch 321/1416
# Processed batch 322/1416
# Processed batch 323/1416
# Processed batch 324/1416
# Processed batch 325/1416
# Processed batch 326/1416
# Processed batch 327/1416
# Processed batch 328/1416
# Processed batch 329/1416
# Processed batch 330/1416
# Processed batch 331/1416
# Processed batch 332/1416
# Processed batch 333/1416
# Processed batch 334/1416
# Processed batch 335/1416
# Processed batch 336/1416
# Processed batch 337/1416
# Processed batch 338/1416
# Processed batch 339/1416
# Processed batch 340/1416
# Processed batch 341/1416
# Processed batch 342/1416
# Processed batch 343/1416
# Processed batch 344/1416
# Processed batch 345/1416
# Processed batch 346/1416
# Processed batch 347/1416
# Processed batch 348/1416
# Processed batch 349/1416
# Processed batch 350/1416
# Processed batch 351/1416
# Processed batch 352/1416
# Processed batch 353/1416
# Processed batch 354/1416
# Processed batch 355/1416
# Processed batch 356/1416
# Processed batch 357/1416
# Processed batch 358/1416
# Processed batch 359/1416
# Processed batch 360/1416
# Processed batch 361/1416
# Processed batch 362/1416
# Processed batch 363/1416
# Processed batch 364/1416
# Processed batch 365/1416
# Processed batch 366/1416
# Processed batch 367/1416
# Processed batch 368/1416
# Processed batch 369/1416
# Processed batch 370/1416
# Processed batch 371/1416
# Processed batch 372/1416
# Processed batch 373/1416
# Processed batch 374/1416
# Processed batch 375/1416
# Processed batch 376/1416
# Processed batch 377/1416
# Processed batch 378/1416
# Processed batch 379/1416
# Processed batch 380/1416
# Processed batch 381/1416
# Processed batch 382/1416
# Processed batch 383/1416
# Processed batch 384/1416
# Processed batch 385/1416
# Processed batch 386/1416
# Processed batch 387/1416
# Processed batch 388/1416
# Processed batch 389/1416
# Processed batch 390/1416
# Processed batch 391/1416
# Processed batch 392/1416
# Processed batch 393/1416
# Processed batch 394/1416
# Processed batch 395/1416
# Processed batch 396/1416
# Processed batch 397/1416
# Processed batch 398/1416
# Processed batch 399/1416
# Processed batch 400/1416
# Processed batch 401/1416
# Processed batch 402/1416
# Processed batch 403/1416
# Processed batch 404/1416
# Processed batch 405/1416
# Processed batch 406/1416
# Processed batch 407/1416
# Processed batch 408/1416
# Processed batch 409/1416
# Processed batch 410/1416
# Processed batch 411/1416
# Processed batch 412/1416
# Processed batch 413/1416
# Processed batch 414/1416
# Processed batch 415/1416
# Processed batch 416/1416
# Processed batch 417/1416
# Processed batch 418/1416
# Processed batch 419/1416
# Processed batch 420/1416
# Processed batch 421/1416
# Processed batch 422/1416
# Processed batch 423/1416
# Processed batch 424/1416
# Processed batch 425/1416
# Processed batch 426/1416
# Processed batch 427/1416
# Processed batch 428/1416
# Processed batch 429/1416
# Processed batch 430/1416
# Processed batch 431/1416
# Processed batch 432/1416
# Processed batch 433/1416
# Processed batch 434/1416
# Processed batch 435/1416
# Processed batch 436/1416
# Processed batch 437/1416
# Processed batch 438/1416
# Processed batch 439/1416
# Processed batch 440/1416
# Processed batch 441/1416
# Processed batch 442/1416
# Processed batch 443/1416
# Processed batch 444/1416
# Processed batch 445/1416
# Processed batch 446/1416
# Processed batch 447/1416
# Processed batch 448/1416
# Processed batch 449/1416
# Processed batch 450/1416
# Processed batch 451/1416
# Processed batch 452/1416
# Processed batch 453/1416
# Processed batch 454/1416
# Processed batch 455/1416
# Processed batch 456/1416
# Processed batch 457/1416
# Processed batch 458/1416
# Processed batch 459/1416
# Processed batch 460/1416
# Processed batch 461/1416
# Processed batch 462/1416
# Processed batch 463/1416
# Processed batch 464/1416
# Processed batch 465/1416
# Processed batch 466/1416
# Processed batch 467/1416
# Processed batch 468/1416
# Processed batch 469/1416
# Processed batch 470/1416
# Processed batch 471/1416
# Processed batch 472/1416
# Processed batch 473/1416
# Processed batch 474/1416
# Processed batch 475/1416
# Processed batch 476/1416
# Processed batch 477/1416
# Processed batch 478/1416
# Processed batch 479/1416
# Processed batch 480/1416
# Processed batch 481/1416
# Processed batch 482/1416
# Processed batch 483/1416
# Processed batch 484/1416
# Processed batch 485/1416
# Processed batch 486/1416
# Processed batch 487/1416
# Processed batch 488/1416
# Processed batch 489/1416
# Processed batch 490/1416
# Processed batch 491/1416
# Processed batch 492/1416
# Processed batch 493/1416
# Processed batch 494/1416
# Processed batch 495/1416
# Processed batch 496/1416
# Processed batch 497/1416
# Processed batch 498/1416
# Processed batch 499/1416
# Processed batch 500/1416
# Processed batch 501/1416
# Processed batch 502/1416
# Processed batch 503/1416
# Processed batch 504/1416
# Processed batch 505/1416
# Processed batch 506/1416
# Processed batch 507/1416
# Processed batch 508/1416
# Processed batch 509/1416
# Processed batch 510/1416
# Processed batch 511/1416
# Processed batch 512/1416
# Processed batch 513/1416
# Processed batch 514/1416
# Processed batch 515/1416
# Processed batch 516/1416
# Processed batch 517/1416
# Processed batch 518/1416
# Processed batch 519/1416
# Processed batch 520/1416
# Processed batch 521/1416
# Processed batch 522/1416
# Processed batch 523/1416
# Processed batch 524/1416
# Processed batch 525/1416
# Processed batch 526/1416
# Processed batch 527/1416
# Processed batch 528/1416
# Processed batch 529/1416
# Processed batch 530/1416
# Processed batch 531/1416
# Processed batch 532/1416
# Processed batch 533/1416
# Processed batch 534/1416
# Processed batch 535/1416
# Processed batch 536/1416
# Processed batch 537/1416
# Processed batch 538/1416
# Processed batch 539/1416
# Processed batch 540/1416
# Processed batch 541/1416
# Processed batch 542/1416
# Processed batch 543/1416
# Processed batch 544/1416
# Processed batch 545/1416
# Processed batch 546/1416
# Processed batch 547/1416
# Processed batch 548/1416
# Processed batch 549/1416
# Processed batch 550/1416
# Processed batch 551/1416
# Processed batch 552/1416
# Processed batch 553/1416
# Processed batch 554/1416
# Processed batch 555/1416
# Processed batch 556/1416
# Processed batch 557/1416
# Processed batch 558/1416
# Processed batch 559/1416
# Processed batch 560/1416
# Processed batch 561/1416
# Processed batch 562/1416
# Processed batch 563/1416
# Processed batch 564/1416
# Processed batch 565/1416
# Processed batch 566/1416
# Processed batch 567/1416
# Processed batch 568/1416
# Processed batch 569/1416
# Processed batch 570/1416
# Processed batch 571/1416
# Processed batch 572/1416
# Processed batch 573/1416
# Processed batch 574/1416
# Processed batch 575/1416
# Processed batch 576/1416
# Processed batch 577/1416
# Processed batch 578/1416
# Processed batch 579/1416
# Processed batch 580/1416
# Processed batch 581/1416
# Processed batch 582/1416
# Processed batch 583/1416
# Processed batch 584/1416
# Processed batch 585/1416
# Processed batch 586/1416
# Processed batch 587/1416
# Processed batch 588/1416
# Processed batch 589/1416
# Processed batch 590/1416
# Processed batch 591/1416
# Processed batch 592/1416
# Processed batch 593/1416
# Processed batch 594/1416
# Processed batch 595/1416
# Processed batch 596/1416
# Processed batch 597/1416
# Processed batch 598/1416
# Processed batch 599/1416
# Processed batch 600/1416
# Processed batch 601/1416
# Processed batch 602/1416
# Processed batch 603/1416
# Processed batch 604/1416
# Processed batch 605/1416
# Processed batch 606/1416
# Processed batch 607/1416
# Processed batch 608/1416
# Processed batch 609/1416
# Processed batch 610/1416
# Processed batch 611/1416
# Processed batch 612/1416
# Processed batch 613/1416
# Processed batch 614/1416
# Processed batch 615/1416
# Processed batch 616/1416
# Processed batch 617/1416
# Processed batch 618/1416
# Processed batch 619/1416
# Processed batch 620/1416
# Processed batch 621/1416
# Processed batch 622/1416
# Processed batch 623/1416
# Processed batch 624/1416
# Processed batch 625/1416
# Processed batch 626/1416
# Processed batch 627/1416
# Processed batch 628/1416
# Processed batch 629/1416
# Processed batch 630/1416
# Processed batch 631/1416
# Processed batch 632/1416
# Processed batch 633/1416
# Processed batch 634/1416
# Processed batch 635/1416
# Processed batch 636/1416
# Processed batch 637/1416
# Processed batch 638/1416
# Processed batch 639/1416
# Processed batch 640/1416
# Processed batch 641/1416
# Processed batch 642/1416
# Processed batch 643/1416
# Processed batch 644/1416
# Processed batch 645/1416
# Processed batch 646/1416
# Processed batch 647/1416
# Processed batch 648/1416
# Processed batch 649/1416
# Processed batch 650/1416
# Processed batch 651/1416
# Processed batch 652/1416
# Processed batch 653/1416
# Processed batch 654/1416
# Processed batch 655/1416
# Processed batch 656/1416
# Processed batch 657/1416
# Processed batch 658/1416
# Processed batch 659/1416
# Processed batch 660/1416
# Processed batch 661/1416
# Processed batch 662/1416
# Processed batch 663/1416
# Processed batch 664/1416
# Processed batch 665/1416
# Processed batch 666/1416
# Processed batch 667/1416
# Processed batch 668/1416
# Processed batch 669/1416
# Processed batch 670/1416
# Processed batch 671/1416
# Processed batch 672/1416
# Processed batch 673/1416
# Processed batch 674/1416
# Processed batch 675/1416
# Processed batch 676/1416
# Processed batch 677/1416
# Processed batch 678/1416
# Processed batch 679/1416
# Processed batch 680/1416
# Processed batch 681/1416
# Processed batch 682/1416
# Processed batch 683/1416
# Processed batch 684/1416
# Processed batch 685/1416
# Processed batch 686/1416
# Processed batch 687/1416
# Processed batch 688/1416
# Processed batch 689/1416
# Processed batch 690/1416
# Processed batch 691/1416
# Processed batch 692/1416
# Processed batch 693/1416
# Processed batch 694/1416
# Processed batch 695/1416
# Processed batch 696/1416
# Processed batch 697/1416
# Processed batch 698/1416
# Processed batch 699/1416
# Processed batch 700/1416
# Processed batch 701/1416
# Processed batch 702/1416
# Processed batch 703/1416
# Processed batch 704/1416
# Processed batch 705/1416
# Processed batch 706/1416
# Processed batch 707/1416
# Processed batch 708/1416
# Processed batch 709/1416
# Processed batch 710/1416
# Processed batch 711/1416
# Processed batch 712/1416
# Processed batch 713/1416
# Processed batch 714/1416
# Processed batch 715/1416
# Processed batch 716/1416
# Processed batch 717/1416
# Processed batch 718/1416
# Processed batch 719/1416
# Processed batch 720/1416
# Processed batch 721/1416
# Processed batch 722/1416
# Processed batch 723/1416
# Processed batch 724/1416
# Processed batch 725/1416
# Processed batch 726/1416
# Processed batch 727/1416
# Processed batch 728/1416
# Processed batch 729/1416
# Processed batch 730/1416
# Processed batch 731/1416
# Processed batch 732/1416
# Processed batch 733/1416
# Processed batch 734/1416
# Processed batch 735/1416
# Processed batch 736/1416
# Processed batch 737/1416
# Processed batch 738/1416
# Processed batch 739/1416
# Processed batch 740/1416
# Processed batch 741/1416
# Processed batch 742/1416
# Processed batch 743/1416
# Processed batch 744/1416
# Processed batch 745/1416
# Processed batch 746/1416
# Processed batch 747/1416
# Processed batch 748/1416
# Processed batch 749/1416
# Processed batch 750/1416
# Processed batch 751/1416
# Processed batch 752/1416
# Processed batch 753/1416
# Processed batch 754/1416
# Processed batch 755/1416
# Processed batch 756/1416
# Processed batch 757/1416
# Processed batch 758/1416
# Processed batch 759/1416
# Processed batch 760/1416
# Processed batch 761/1416
# Processed batch 762/1416
# Processed batch 763/1416
# Processed batch 764/1416
# Processed batch 765/1416
# Processed batch 766/1416
# Processed batch 767/1416
# Processed batch 768/1416
# Processed batch 769/1416
# Processed batch 770/1416
# Processed batch 771/1416
# Processed batch 772/1416
# Processed batch 773/1416
# Processed batch 774/1416
# Processed batch 775/1416
# Processed batch 776/1416
# Processed batch 777/1416
# Processed batch 778/1416
# Processed batch 779/1416
# Processed batch 780/1416
# Processed batch 781/1416
# Processed batch 782/1416
# Processed batch 783/1416
# Processed batch 784/1416
# Processed batch 785/1416
# Processed batch 786/1416
# Processed batch 787/1416
# Processed batch 788/1416
# Processed batch 789/1416
# Processed batch 790/1416
# Processed batch 791/1416
# Processed batch 792/1416
# Processed batch 793/1416
# Processed batch 794/1416
# Processed batch 795/1416
# Processed batch 796/1416
# Processed batch 797/1416
# Processed batch 798/1416
# Processed batch 799/1416
# Processed batch 800/1416
# Processed batch 801/1416
# Processed batch 802/1416
# Processed batch 803/1416
# Processed batch 804/1416
# Processed batch 805/1416
# Processed batch 806/1416
# Processed batch 807/1416
# Processed batch 808/1416
# Processed batch 809/1416
# Processed batch 810/1416
# Processed batch 811/1416
# Processed batch 812/1416
# Processed batch 813/1416
# Processed batch 814/1416
# Processed batch 815/1416
# Processed batch 816/1416
# Processed batch 817/1416
# Processed batch 818/1416
# Processed batch 819/1416
# Processed batch 820/1416
# Processed batch 821/1416
# Processed batch 822/1416
# Processed batch 823/1416
# Processed batch 824/1416
# Processed batch 825/1416
# Processed batch 826/1416
# Processed batch 827/1416
# Processed batch 828/1416
# Processed batch 829/1416
# Processed batch 830/1416
# Processed batch 831/1416
# Processed batch 832/1416
# Processed batch 833/1416
# Processed batch 834/1416
# Processed batch 835/1416
# Processed batch 836/1416
# Processed batch 837/1416
# Processed batch 838/1416
# Processed batch 839/1416
# Processed batch 840/1416
# Processed batch 841/1416
# Processed batch 842/1416
# Processed batch 843/1416
# Processed batch 844/1416
# Processed batch 845/1416
# Processed batch 846/1416
# Processed batch 847/1416
# Processed batch 848/1416
# Processed batch 849/1416
# Processed batch 850/1416
# Processed batch 851/1416
# Processed batch 852/1416
# Processed batch 853/1416
# Processed batch 854/1416
# Processed batch 855/1416
# Processed batch 856/1416
# Processed batch 857/1416
# Processed batch 858/1416
# Processed batch 859/1416
# Processed batch 860/1416
# Processed batch 861/1416
# Processed batch 862/1416
# Processed batch 863/1416
# Processed batch 864/1416
# Processed batch 865/1416
# Processed batch 866/1416
# Processed batch 867/1416
# Processed batch 868/1416
# Processed batch 869/1416
# Processed batch 870/1416
# Processed batch 871/1416
# Processed batch 872/1416
# Processed batch 873/1416
# Processed batch 874/1416
# Processed batch 875/1416
# Processed batch 876/1416
# Processed batch 877/1416
# Processed batch 878/1416
# Processed batch 879/1416
# Processed batch 880/1416
# Processed batch 881/1416
# Processed batch 882/1416
# Processed batch 883/1416
# Processed batch 884/1416
# Processed batch 885/1416
# Processed batch 886/1416
# Processed batch 887/1416
# Processed batch 888/1416
# Processed batch 889/1416
# Processed batch 890/1416
# Processed batch 891/1416
# Processed batch 892/1416
# Processed batch 893/1416
# Processed batch 894/1416
# Processed batch 895/1416
# Processed batch 896/1416
# Processed batch 897/1416
# Processed batch 898/1416
# Processed batch 899/1416
# Processed batch 900/1416
# Processed batch 901/1416
# Processed batch 902/1416
# Processed batch 903/1416
# Processed batch 904/1416
# Processed batch 905/1416
# Processed batch 906/1416
# Processed batch 907/1416
# Processed batch 908/1416
# Processed batch 909/1416
# Processed batch 910/1416
# Processed batch 911/1416
# Processed batch 912/1416
# Processed batch 913/1416
# Processed batch 914/1416
# Processed batch 915/1416
# Processed batch 916/1416
# Processed batch 917/1416
# Processed batch 918/1416
# Processed batch 919/1416
# Processed batch 920/1416
# Processed batch 921/1416
# Processed batch 922/1416
# Processed batch 923/1416
# Processed batch 924/1416
# Processed batch 925/1416
# Processed batch 926/1416
# Processed batch 927/1416
# Processed batch 928/1416
# Processed batch 929/1416
# Processed batch 930/1416
# Processed batch 931/1416
# Processed batch 932/1416
# Processed batch 933/1416
# Processed batch 934/1416
# Processed batch 935/1416
# Processed batch 936/1416
# Processed batch 937/1416
# Processed batch 938/1416
# Processed batch 939/1416
# Processed batch 940/1416
# Processed batch 941/1416
# Processed batch 942/1416
# Processed batch 943/1416
# Processed batch 944/1416
# Processed batch 945/1416
# Processed batch 946/1416
# Processed batch 947/1416
# Processed batch 948/1416
# Processed batch 949/1416
# Processed batch 950/1416
# Processed batch 951/1416
# Processed batch 952/1416
# Processed batch 953/1416
# Processed batch 954/1416
# Processed batch 955/1416
# Processed batch 956/1416
# Processed batch 957/1416
# Processed batch 958/1416
# Processed batch 959/1416
# Processed batch 960/1416
# Processed batch 961/1416
# Processed batch 962/1416
# Processed batch 963/1416
# Processed batch 964/1416
# Processed batch 965/1416
# Processed batch 966/1416
# Processed batch 967/1416
# Processed batch 968/1416
# Processed batch 969/1416
# Processed batch 970/1416
# Processed batch 971/1416
# Processed batch 972/1416
# Processed batch 973/1416
# Processed batch 974/1416
# Processed batch 975/1416
# Processed batch 976/1416
# Processed batch 977/1416
# Processed batch 978/1416
# Processed batch 979/1416
# Processed batch 980/1416
# Processed batch 981/1416
# Processed batch 982/1416
# Processed batch 983/1416
# Processed batch 984/1416
# Processed batch 985/1416
# Processed batch 986/1416
# Processed batch 987/1416
# Processed batch 988/1416
# Processed batch 989/1416
# Processed batch 990/1416
# Processed batch 991/1416
# Processed batch 992/1416
# Processed batch 993/1416
# Processed batch 994/1416
# Processed batch 995/1416
# Processed batch 996/1416
# Processed batch 997/1416
# Processed batch 998/1416
# Processed batch 999/1416
# Processed batch 1000/1416
# Processed batch 1001/1416
# Processed batch 1002/1416
# Processed batch 1003/1416
# Processed batch 1004/1416
# Processed batch 1005/1416
# Processed batch 1006/1416
# Processed batch 1007/1416
# Processed batch 1008/1416
# Processed batch 1009/1416
# Processed batch 1010/1416
# Processed batch 1011/1416
# Processed batch 1012/1416
# Processed batch 1013/1416
# Processed batch 1014/1416
# Processed batch 1015/1416
# Processed batch 1016/1416
# Processed batch 1017/1416
# Processed batch 1018/1416
# Processed batch 1019/1416
# Processed batch 1020/1416
# Processed batch 1021/1416
# Processed batch 1022/1416
# Processed batch 1023/1416
# Processed batch 1024/1416
# Processed batch 1025/1416
# Processed batch 1026/1416
# Processed batch 1027/1416
# Processed batch 1028/1416
# Processed batch 1029/1416
# Processed batch 1030/1416
# Processed batch 1031/1416
# Processed batch 1032/1416
# Processed batch 1033/1416
# Processed batch 1034/1416
# Processed batch 1035/1416
# Processed batch 1036/1416
# Processed batch 1037/1416
# Processed batch 1038/1416
# Processed batch 1039/1416
# Processed batch 1040/1416
# Processed batch 1041/1416
# Processed batch 1042/1416
# Processed batch 1043/1416
# Processed batch 1044/1416
# Processed batch 1045/1416
# Processed batch 1046/1416
# Processed batch 1047/1416
# Processed batch 1048/1416
# Processed batch 1049/1416
# Processed batch 1050/1416
# Processed batch 1051/1416
# Processed batch 1052/1416
# Processed batch 1053/1416
# Processed batch 1054/1416
# Processed batch 1055/1416
# Processed batch 1056/1416
# Processed batch 1057/1416
# Processed batch 1058/1416
# Processed batch 1059/1416
# Processed batch 1060/1416
# Processed batch 1061/1416
# Processed batch 1062/1416
# Processed batch 1063/1416
# Processed batch 1064/1416
# Processed batch 1065/1416
# Processed batch 1066/1416
# Processed batch 1067/1416
# Processed batch 1068/1416
# Processed batch 1069/1416
# Processed batch 1070/1416
# Processed batch 1071/1416
# Processed batch 1072/1416
# Processed batch 1073/1416
# Processed batch 1074/1416
# Processed batch 1075/1416
# Processed batch 1076/1416
# Processed batch 1077/1416
# Processed batch 1078/1416
# Processed batch 1079/1416
# Processed batch 1080/1416
# Processed batch 1081/1416
# Processed batch 1082/1416
# Processed batch 1083/1416
# Processed batch 1084/1416
# Processed batch 1085/1416
# Processed batch 1086/1416
# Processed batch 1087/1416
# Processed batch 1088/1416
# Processed batch 1089/1416
# Processed batch 1090/1416
# Processed batch 1091/1416
# Processed batch 1092/1416
# Processed batch 1093/1416
# Processed batch 1094/1416
# Processed batch 1095/1416
# Processed batch 1096/1416
# Processed batch 1097/1416
# Processed batch 1098/1416
# Processed batch 1099/1416
# Processed batch 1100/1416
# Processed batch 1101/1416
# Processed batch 1102/1416
# Processed batch 1103/1416
# Processed batch 1104/1416
# Processed batch 1105/1416
# Processed batch 1106/1416
# Processed batch 1107/1416
# Processed batch 1108/1416
# Processed batch 1109/1416
# Processed batch 1110/1416
# Processed batch 1111/1416
# Processed batch 1112/1416
# Processed batch 1113/1416
# Processed batch 1114/1416
# Processed batch 1115/1416
# Processed batch 1116/1416
# Processed batch 1117/1416
# Processed batch 1118/1416
# Processed batch 1119/1416
# Processed batch 1120/1416
# Processed batch 1121/1416
# Processed batch 1122/1416
# Processed batch 1123/1416
# Processed batch 1124/1416
# Processed batch 1125/1416
# Processed batch 1126/1416
# Processed batch 1127/1416
# Processed batch 1128/1416
# Processed batch 1129/1416
# Processed batch 1130/1416
# Processed batch 1131/1416
# Processed batch 1132/1416
# Processed batch 1133/1416
# Processed batch 1134/1416
# Processed batch 1135/1416
# Processed batch 1136/1416
# Processed batch 1137/1416
# Processed batch 1138/1416
# Processed batch 1139/1416
# Processed batch 1140/1416
# Processed batch 1141/1416
# Processed batch 1142/1416
# Processed batch 1143/1416
# Processed batch 1144/1416
# Processed batch 1145/1416
# Processed batch 1146/1416
# Processed batch 1147/1416
# Processed batch 1148/1416
# Processed batch 1149/1416
# Processed batch 1150/1416
# Processed batch 1151/1416
# Processed batch 1152/1416
# Processed batch 1153/1416
# Processed batch 1154/1416
# Processed batch 1155/1416
# Processed batch 1156/1416
# Processed batch 1157/1416
# Processed batch 1158/1416
# Processed batch 1159/1416
# Processed batch 1160/1416
# Processed batch 1161/1416
# Processed batch 1162/1416
# Processed batch 1163/1416
# Processed batch 1164/1416
# Processed batch 1165/1416
# Processed batch 1166/1416
# Processed batch 1167/1416
# Processed batch 1168/1416
# Processed batch 1169/1416
# Processed batch 1170/1416
# Processed batch 1171/1416
# Processed batch 1172/1416
# Processed batch 1173/1416
# Processed batch 1174/1416
# Processed batch 1175/1416
# Processed batch 1176/1416
# Processed batch 1177/1416
# Processed batch 1178/1416
# Processed batch 1179/1416
# Processed batch 1180/1416
# Processed batch 1181/1416
# Processed batch 1182/1416
# Processed batch 1183/1416
# Processed batch 1184/1416
# Processed batch 1185/1416
# Processed batch 1186/1416
# Processed batch 1187/1416
# Processed batch 1188/1416
# Processed batch 1189/1416
# Processed batch 1190/1416
# Processed batch 1191/1416
# Processed batch 1192/1416
# Processed batch 1193/1416
# Processed batch 1194/1416
# Processed batch 1195/1416
# Processed batch 1196/1416
# Processed batch 1197/1416
# Processed batch 1198/1416
# Processed batch 1199/1416
# Processed batch 1200/1416
# Processed batch 1201/1416
# Processed batch 1202/1416
# Processed batch 1203/1416
# Processed batch 1204/1416
# Processed batch 1205/1416
# Processed batch 1206/1416
# Processed batch 1207/1416
# Processed batch 1208/1416
# Processed batch 1209/1416
# Processed batch 1210/1416
# Processed batch 1211/1416
# Processed batch 1212/1416
# Processed batch 1213/1416
# Processed batch 1214/1416
# Processed batch 1215/1416
# Processed batch 1216/1416
# Processed batch 1217/1416
# Processed batch 1218/1416
# Processed batch 1219/1416
# Processed batch 1220/1416
# Processed batch 1221/1416
# Processed batch 1222/1416
# Processed batch 1223/1416
# Processed batch 1224/1416
# Processed batch 1225/1416
# Processed batch 1226/1416
# Processed batch 1227/1416
# Processed batch 1228/1416
# Processed batch 1229/1416
# Processed batch 1230/1416
# Processed batch 1231/1416
# Processed batch 1232/1416
# Processed batch 1233/1416
# Processed batch 1234/1416
# Processed batch 1235/1416
# Processed batch 1236/1416
# Processed batch 1237/1416
# Processed batch 1238/1416
# Processed batch 1239/1416
# Processed batch 1240/1416
# Processed batch 1241/1416
# Processed batch 1242/1416
# Processed batch 1243/1416
# Processed batch 1244/1416
# Processed batch 1245/1416
# Processed batch 1246/1416
# Processed batch 1247/1416
# Processed batch 1248/1416
# Processed batch 1249/1416
# Processed batch 1250/1416
# Processed batch 1251/1416
# Processed batch 1252/1416
# Processed batch 1253/1416
# Processed batch 1254/1416
# Processed batch 1255/1416
# Processed batch 1256/1416
# Processed batch 1257/1416
# Processed batch 1258/1416
# Processed batch 1259/1416
# Processed batch 1260/1416
# Processed batch 1261/1416
# Processed batch 1262/1416
# Processed batch 1263/1416
# Processed batch 1264/1416
# Processed batch 1265/1416
# Processed batch 1266/1416
# Processed batch 1267/1416
# Processed batch 1268/1416
# Processed batch 1269/1416
# Processed batch 1270/1416
# Processed batch 1271/1416
# Processed batch 1272/1416
# Processed batch 1273/1416
# Processed batch 1274/1416
# Processed batch 1275/1416
# Processed batch 1276/1416
# Processed batch 1277/1416
# Processed batch 1278/1416
# Processed batch 1279/1416
# Processed batch 1280/1416
# Processed batch 1281/1416
# Processed batch 1282/1416
# Processed batch 1283/1416
# Processed batch 1284/1416
# Processed batch 1285/1416
# Processed batch 1286/1416
# Processed batch 1287/1416
# Processed batch 1288/1416
# Processed batch 1289/1416
# Processed batch 1290/1416
# Processed batch 1291/1416
# Processed batch 1292/1416
# Processed batch 1293/1416
# Processed batch 1294/1416
# Processed batch 1295/1416
# Processed batch 1296/1416
# Processed batch 1297/1416
# Processed batch 1298/1416
# Processed batch 1299/1416
# Processed batch 1300/1416
# Processed batch 1301/1416
# Processed batch 1302/1416
# Processed batch 1303/1416
# Processed batch 1304/1416
# Processed batch 1305/1416
# Processed batch 1306/1416
# Processed batch 1307/1416
# Processed batch 1308/1416
# Processed batch 1309/1416
# Processed batch 1310/1416
# Processed batch 1311/1416
# Processed batch 1312/1416
# Processed batch 1313/1416
# Processed batch 1314/1416
# Processed batch 1315/1416
# Processed batch 1316/1416
# Processed batch 1317/1416
# Processed batch 1318/1416
# Processed batch 1319/1416
# Processed batch 1320/1416
# Processed batch 1321/1416
# Processed batch 1322/1416
# Processed batch 1323/1416
# Processed batch 1324/1416
# Processed batch 1325/1416
# Processed batch 1326/1416
# Processed batch 1327/1416
# Processed batch 1328/1416
# Processed batch 1329/1416
# Processed batch 1330/1416
# Processed batch 1331/1416
# Processed batch 1332/1416
# Processed batch 1333/1416
# Processed batch 1334/1416
# Processed batch 1335/1416
# Processed batch 1336/1416
# Processed batch 1337/1416
# Processed batch 1338/1416
# Processed batch 1339/1416
# Processed batch 1340/1416
# Processed batch 1341/1416
# Processed batch 1342/1416
# Processed batch 1343/1416
# Processed batch 1344/1416
# Processed batch 1345/1416
# Processed batch 1346/1416
# Processed batch 1347/1416
# Processed batch 1348/1416
# Processed batch 1349/1416
# Processed batch 1350/1416
# Processed batch 1351/1416
# Processed batch 1352/1416
# Processed batch 1353/1416
# Processed batch 1354/1416
# Processed batch 1355/1416
# Processed batch 1356/1416
# Processed batch 1357/1416
# Processed batch 1358/1416
# Processed batch 1359/1416
# Processed batch 1360/1416
# Processed batch 1361/1416
# Processed batch 1362/1416
# Processed batch 1363/1416
# Processed batch 1364/1416
# Processed batch 1365/1416
# Processed batch 1366/1416
# Processed batch 1367/1416
# Processed batch 1368/1416
# Processed batch 1369/1416
# Processed batch 1370/1416
# Processed batch 1371/1416
# Processed batch 1372/1416
# Processed batch 1373/1416
# Processed batch 1374/1416
# Processed batch 1375/1416
# Processed batch 1376/1416
# Processed batch 1377/1416
# Processed batch 1378/1416
# Processed batch 1379/1416
# Processed batch 1380/1416
# Processed batch 1381/1416
# Processed batch 1382/1416
# Processed batch 1383/1416
# Processed batch 1384/1416
# Processed batch 1385/1416
# Processed batch 1386/1416
# Processed batch 1387/1416
# Processed batch 1388/1416
# Processed batch 1389/1416
# Processed batch 1390/1416
# Processed batch 1391/1416
# Processed batch 1392/1416
# Processed batch 1393/1416
# Processed batch 1394/1416
# Processed batch 1395/1416
# Processed batch 1396/1416
# Processed batch 1397/1416
# Processed batch 1398/1416
# Processed batch 1399/1416
# Processed batch 1400/1416
# Processed batch 1401/1416
# Processed batch 1402/1416
# Processed batch 1403/1416
# Processed batch 1404/1416
# Processed batch 1405/1416
# Processed batch 1406/1416
# Processed batch 1407/1416
# Processed batch 1408/1416
# Processed batch 1409/1416
# Processed batch 1410/1416
# Processed batch 1411/1416
# Processed batch 1412/1416
# Processed batch 1413/1416
# Processed batch 1414/1416
# Processed batch 1415/1416
# Processed batch 1416/1416
# Test features shape: (11324, 1284)
#
# Splitting data into training and validation sets...
# X_train shape: (1072, 1284) | X_val shape: (268, 1284)

# %%
# sklearn model
print("\nTraining Gradient Boosting Regressor...")
model = GradientBoostingRegressor(n_estimators=5000, learning_rate=0.05, max_depth=3, random_state=42)
model.fit(X_train, y_train)
print("Model training completed on training split.")
# Out:
# Training Gradient Boosting Regressor...
# Model training completed on training split.

# %%
val_preds = model.predict(X_val)
initial_corr, _ = spearmanr(y_val, val_preds)
print("\nInitial Validation Spearman Correlation:", initial_corr)
if initial_corr < 0:
    val_preds = -val_preds
    print("Predictions flipped due to negative correlation.")
    initial_corr, _ = spearmanr(y_val, val_preds)
    print("Validation Spearman Correlation after flipping:", initial_corr)
val_preds_ranked = pd.Series(val_preds).rank(method='dense').values
ranked_corr, _ = spearmanr(y_val, val_preds_ranked)
print("Validation Spearman Correlation (Ranked Predictions):", ranked_corr)
# Out:
# Initial Validation Spearman Correlation: 0.4946213370130747
# Validation Spearman Correlation (Ranked Predictions): 0.4946213370130747

# %%
print("\nRetraining model on full training data...")
model.fit(train_features, y_train_full)
test_preds = model.predict(test_features)
train_preds = model.predict(train_features)
train_corr, _ = spearmanr(y_train_full, train_preds)
print("Full Training Spearman Correlation:", train_corr)
if train_corr < 0:
    test_preds = -test_preds
    print("Test predictions flipped based on training correlation.")
test_preds_ranked = pd.Series(test_preds).rank(method='dense').values
# Out:
# Retraining model on full training data...
# Full Training Spearman Correlation: 0.9526268768444984

# %%
submission = test_df[['mutant']].copy()
submission['DMS_score_predicted'] = test_preds_ranked
submission.to_csv('predictions.csv', index=False)
print("\nSubmission saved to predictions.csv")
# Out:
# Submission saved to predictions.csv

# %%
import pandas as pd

predictions = pd.read_csv('predictions.csv')

top10 = predictions.sort_values('DMS_score_predicted', ascending=False).head(10)

with open('top10.txt', 'w') as f:
    for mutant in top10['mutant']:
        f.write(f"{mutant}\n")

print("Top 10 mutants saved to top10.txt")
# Out:
# Top 10 mutants saved to top10.txt

# %%
# trying wiht neural network



# ---------------------------------------------------
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.reshape(-1, 1), dtype=torch.float32)
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

class Net(nn.Module):
    def __init__(self, input_size):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(128, 64)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        x = self.relu1(self.fc1(x))
        x = self.relu2(self.fc2(x))
        return self.fc3(x)

net = Net(input_size=X_train.shape[1]).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=1e-3)

n_epochs = 50
for epoch in range(n_epochs):
    net.train()
    epoch_loss = 0
    for xb, yb in train_loader:
        xb = xb.to(device)
        yb = yb.to(device)
        optimizer.zero_grad()
        preds = net(xb)
        loss = criterion(preds, yb)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    print(f"Epoch {epoch+1}/{n_epochs}, Loss: {epoch_loss/len(train_loader):.4f}")
# Out:
# Epoch 1/50, Loss: 0.1107
# Epoch 2/50, Loss: 0.0424
# Epoch 3/50, Loss: 0.0461
# Epoch 4/50, Loss: 0.0430
# Epoch 5/50, Loss: 0.0410
# Epoch 6/50, Loss: 0.0403
# Epoch 7/50, Loss: 0.0406
# Epoch 8/50, Loss: 0.0451
# Epoch 9/50, Loss: 0.0455
# Epoch 10/50, Loss: 0.0419
# Epoch 11/50, Loss: 0.0404
# Epoch 12/50, Loss: 0.0398
# Epoch 13/50, Loss: 0.0400
# Epoch 14/50, Loss: 0.0385
# Epoch 15/50, Loss: 0.0410
# Epoch 16/50, Loss: 0.0395
# Epoch 17/50, Loss: 0.0387
# Epoch 18/50, Loss: 0.0412
# Epoch 19/50, Loss: 0.0427
# Epoch 20/50, Loss: 0.0404
# Epoch 21/50, Loss: 0.0396
# Epoch 22/50, Loss: 0.0390
# Epoch 23/50, Loss: 0.0394
# Epoch 24/50, Loss: 0.0391
# Epoch 25/50, Loss: 0.0399
# Epoch 26/50, Loss: 0.0394
# Epoch 27/50, Loss: 0.0420
# Epoch 28/50, Loss: 0.0408
# Epoch 29/50, Loss: 0.0407
# Epoch 30/50, Loss: 0.0394
# Epoch 31/50, Loss: 0.0388
# Epoch 32/50, Loss: 0.0388
# Epoch 33/50, Loss: 0.0384
# Epoch 34/50, Loss: 0.0416
# Epoch 35/50, Loss: 0.0384
# Epoch 36/50, Loss: 0.0405
# Epoch 37/50, Loss: 0.0410
# Epoch 38/50, Loss: 0.0386
# Epoch 39/50, Loss: 0.0399
# Epoch 40/50, Loss: 0.0407
# Epoch 41/50, Loss: 0.0386
# Epoch 42/50, Loss: 0.0385
# Epoch 43/50, Loss: 0.0390
# Epoch 44/50, Loss: 0.0399
# Epoch 45/50, Loss: 0.0392
# Epoch 46/50, Loss: 0.0388
# Epoch 47/50, Loss: 0.0389
# Epoch 48/50, Loss: 0.0394
# Epoch 49/50, Loss: 0.0382
# Epoch 50/50, Loss: 0.0394

# %%
# evlauation

net.eval()
with torch.no_grad():
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
    val_preds_nn = net(X_val_tensor).cpu().numpy().ravel()
print("Neural Network Validation Spearman Correlation:", spearmanr(y_val, val_preds_nn)[0])
# Out:
# Neural Network Validation Spearman Correlation: 0.3230852838092417

# %%
# xgboos tmodel

import xgboost as xgb

print("\nTraining XGBoost Regressor...")
# 20.65 % accuracy:
# model = xgb.XGBRegressor(n_estimators=30000, learning_rate=0.005, max_depth=3, random_state=42)
model = xgb.XGBRegressor(n_estimators=5000, learning_rate=0.05, max_depth=3, random_state=42)
model.fit(X_train, y_train)
print("Model training completed on training split.")

# Validation Predictions
val_preds = model.predict(X_val)
initial_corr, _ = spearmanr(y_val, val_preds)
print("\nInitial Validation Spearman Correlation:", initial_corr)
if initial_corr < 0:
    val_preds = -val_preds
    print("Predictions flipped due to negative correlation.")
    initial_corr, _ = spearmanr(y_val, val_preds)
    print("Validation Spearman Correlation after flipping:", initial_corr)
val_preds_ranked = pd.Series(val_preds).rank(method='dense').values
ranked_corr, _ = spearmanr(y_val, val_preds_ranked)
print("Validation Spearman Correlation (Ranked Predictions):", ranked_corr)

print("\nRetraining model on full training data...")
model.fit(train_features, y_train_full)
test_preds = model.predict(test_features)
train_preds = model.predict(train_features)
train_corr, _ = spearmanr(y_train_full, train_preds)
print("Full Training Spearman Correlation:", train_corr)
if train_corr < 0:
    test_preds = -test_preds
    print("Test predictions flipped based on training correlation.")
test_preds_ranked = pd.Series(test_preds).rank(method='dense').values

submission = test_df[['mutant']].copy()
submission['DMS_score_predicted'] = test_preds_ranked
submission.to_csv('predictions.csv', index=False)
print("\nSubmission saved to predictions.csv")
# Out:
# Training XGBoost Regressor...
# Model training completed on training split.
#
# Initial Validation Spearman Correlation: 0.6434167885340548
# Validation Spearman Correlation (Ranked Predictions): 0.6434167885340548
#
# Retraining model on full training data...
# Full Training Spearman Correlation: 0.998927141451332
#
# Submission saved to predictions.csv

# %%
# this is to generate uncertain predictions
import numpy as np

num_models = 5
ensemble_preds = np.zeros((len(test_features), num_models))

for i in range(num_models):
    bootstrap_idx = np.random.choice(len(X_train), size=len(X_train), replace=True)
    X_train_boot = X_train[bootstrap_idx]
    y_train_boot = y_train[bootstrap_idx]
    model_boot = xgb.XGBRegressor(n_estimators=5000, learning_rate=0.05,
                                  max_depth=3, random_state=42 + i)
    model_boot.fit(X_train_boot, y_train_boot)

    ensemble_preds[:, i] = model_boot.predict(test_features)

uncertainty = ensemble_preds.std(axis=1)
top_uncertain_indices = np.argsort(-uncertainty)[:100]

# extract the mutants
query_mutants = test_df.loc[top_uncertain_indices, 'mutant'].tolist()

with open("query.txt", "w") as f:
    for mutant in query_mutants:
        f.write(mutant + "\n")

print("\nQuery file 'query.txt' created with the 100 most uncertain mutants.")
# Out:
# Query file 'query.txt' created with the 100 most uncertain mutants.

# %%
import pandas as pd
# loading
predictions = pd.read_csv('predictions.csv')

top10 = predictions.sort_values('DMS_score_predicted', ascending=False).head(10)
with open('top10.txt', 'w') as f:
    for mutant in top10['mutant']:
        f.write(f"{mutant}\n")

print("Top 10 mutants saved to top10.txt")
# Out:
# Top 10 mutants saved to top10.txt
